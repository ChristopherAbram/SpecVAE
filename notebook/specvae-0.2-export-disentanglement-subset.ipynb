# %% [markdown]
# # Select subset of compounds for disentanglement

# %%
import os
import numpy as np
import pandas as pd
from specvae import utils
from specvae.dataset import Spectra
from IPython.display import display
import plotly.express as px

# %%
# Parameters
dataset = "HMDB"

# %% [markdown]
# ## Load data

# %%
if dataset == 'MoNA':
    base_path = utils.get_project_path() / '.data' / 'MoNA'
    data_path = base_path / 'MoNA_full.csv'
    metadata_path = base_path / 'MoNA_meta.npy'
elif dataset == 'HMDB':
    base_path = utils.get_project_path() / '.data' / 'HMDB'
    data_path = base_path / 'HMDB_full.csv'
    metadata_path = base_path / 'HMDB_meta.npy'

metadata = None
if os.path.exists(metadata_path):
    metadata = np.load(metadata_path, allow_pickle=True).item()

# %% [markdown]
# ## Dataset

# %%
df = Spectra.open(data_path)
df.describe()
# Out:
#          Unnamed: 0  collision_energy  ionization_mode  ionization_mode_id  \
# count  92916.000000      92916.000000     92916.000000        92916.000000
# mean   46457.500000         23.333333         0.500000            0.500000
# std    26822.683143         12.472258         0.500003            0.500003
# min        0.000000         10.000000         0.000000            0.000000
# 25%    23228.750000         10.000000         0.000000            0.000000
# 50%    46457.500000         20.000000         0.500000            0.500000
# 75%    69686.250000         40.000000         1.000000            1.000000
# max    92915.000000         40.000000         1.000000            1.000000
#
#          kingdom_id  superclass_id      class_id   subclass_id
# count  92916.000000   92916.000000  92916.000000  92916.000000
# mean       0.997159       9.045590    103.739119    240.160855
# std        0.053228       4.776928     48.438618    143.486602
# min        0.000000       0.000000     -1.000000     -1.000000
# 25%        1.000000       7.000000     87.000000    133.000000
# 50%        1.000000       7.000000     87.000000    198.000000
# 75%        1.000000      12.000000    115.000000    395.000000
# max        1.000000      21.000000    252.000000    404.000000

# %% [markdown]
# ## Select by collision energy

# %%
df1 = df[df['collision_energy'].isin([5*i for i in range(1, 21)])].copy()

# %%
df1.groupby('collision_energy').size().reset_index(name='counts')
# Out:
#    collision_energy  counts
# 0                10   30972
# 1                20   30972
# 2                40   30972

# %%
fig = px.histogram(df1, x='collision_energy', width=1000, height=500)
fig.show()

# %%
df1 = df1[df1['instrument_type_id'].isin([1, 0, 7, 2, 10, 17])].copy()
df_it = df1.groupby('instrument_type_id').size().reset_index(name='counts')
df_it
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Workspace\anaconda3\envs\specvae\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# D:\Workspace\anaconda3\envs\specvae\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Workspace\anaconda3\envs\specvae\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'instrument_type_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20952/1434296416.py in <module>
# ----> 1 df1 = df1[df1['instrument_type_id'].isin([1, 0, 7, 2, 10, 17])].copy()
#       2 df_it = df1.groupby('instrument_type_id').size().reset_index(name='counts')
#       3 df_it
#
# D:\Workspace\anaconda3\envs\specvae\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# D:\Workspace\anaconda3\envs\specvae\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'instrument_type_id'

# %%
fig = px.pie(df_it, values='counts', names='instrument_type_id', hover_data=None, width=1000, height=500)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
df_im = df1.groupby('ionization_mode_id').size().reset_index(name='counts')
df_im
# Out:
#    ionization_mode_id  counts
# 0                   0   46458
# 1                   1   46458

# %%
fig = px.pie(df_im, values='counts', names='ionization_mode_id', hover_data=None, width=1000, height=500)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
df1
# Out:
#        Unnamed: 0                                           spectrum  \
# 0               0  29.03912516:0.7243706179 57.03403978:4.5379311...
# 1               1  29.03912516:9.587454265 55.01838972:2.54439610...
# 2               2  27.0234751:6.640847978 29.03912516:6.54806256 ...
# 3               3  27.0234751:0.03173920628 29.00273965:0.0149975...
# 4               4  27.0234751:0.3171135208 29.00273965:0.47242358...
# ...           ...                                                ...
# 92911       92911  41.03912516:3.321276734 43.05477522:1.41515277...
# 92912       92912  27.0234751:1.818499485 41.03912516:10.00329657...
# 92913       92913  17.00273965:0.1727702035 43.05477522:0.1824458...
# 92914       92914  44.99765427:0.9915595017 59.01330434:5.8014561...
# 92915       92915  41.00273965:7.918795001 43.01838972:3.11974796...
#
#        collision_energy          HMDB_map  \
# 0                    10  HMDB:HMDB0031492
# 1                    20  HMDB:HMDB0031492
# 2                    40  HMDB:HMDB0031492
# 3                    10  HMDB:HMDB0031492
# 4                    20  HMDB:HMDB0031492
# ...                 ...               ...
# 92911                20  HMDB:HMDB0012534
# 92912                40  HMDB:HMDB0012534
# 92913                10  HMDB:HMDB0012534
# 92914                20  HMDB:HMDB0012534
# 92915                40  HMDB:HMDB0012534
#
#                                                SMILES  split         id  \
# 0                                      CCC(=O)C(=O)CC  train  HMDB31492
# 1                                      CCC(=O)C(=O)CC  train  HMDB31492
# 2                                      CCC(=O)C(=O)CC  train  HMDB31492
# 3                                      CCC(=O)C(=O)CC  train  HMDB31492
# 4                                      CCC(=O)C(=O)CC  train  HMDB31492
# ...                                               ...    ...        ...
# 92911  CC\C=C/C\C=C/C=C/[C@H](O)C\C=C/C\C=C/CCCC(O)=O   test  HMDB12534
# 92912  CC\C=C/C\C=C/C=C/[C@H](O)C\C=C/C\C=C/CCCC(O)=O   test  HMDB12534
# 92913  CC\C=C/C\C=C/C=C/[C@H](O)C\C=C/C\C=C/CCCC(O)=O   test  HMDB12534
# 92914  CC\C=C/C\C=C/C=C/[C@H](O)C\C=C/C\C=C/CCCC(O)=O   test  HMDB12534
# 92915  CC\C=C/C\C=C/C=C/[C@H](O)C\C=C/C\C=C/CCCC(O)=O   test  HMDB12534
#
#        ionization_mode  ionization_mode_id            kingdom  \
# 0                    1                   1  Organic compounds
# 1                    1                   1  Organic compounds
# 2                    1                   1  Organic compounds
# 3                    0                   0  Organic compounds
# 4                    0                   0  Organic compounds
# ...                ...                 ...                ...
# 92911                1                   1  Organic compounds
# 92912                1                   1  Organic compounds
# 92913                0                   0  Organic compounds
# 92914                0                   0  Organic compounds
# 92915                0                   0  Organic compounds
#
#                             superclass                   class  \
# 0             Organic oxygen compounds  Organooxygen compounds
# 1             Organic oxygen compounds  Organooxygen compounds
# 2             Organic oxygen compounds  Organooxygen compounds
# 3             Organic oxygen compounds  Organooxygen compounds
# 4             Organic oxygen compounds  Organooxygen compounds
# ...                                ...                     ...
# 92911  Lipids and lipid-like molecules             Fatty Acyls
# 92912  Lipids and lipid-like molecules             Fatty Acyls
# 92913  Lipids and lipid-like molecules             Fatty Acyls
# 92914  Lipids and lipid-like molecules             Fatty Acyls
# 92915  Lipids and lipid-like molecules             Fatty Acyls
#
#                  subclass  kingdom_id  superclass_id  class_id  subclass_id  \
# 0      Carbonyl compounds           1             14       159           87
# 1      Carbonyl compounds           1             14       159           87
# 2      Carbonyl compounds           1             14       159           87
# 3      Carbonyl compounds           1             14       159           87
# 4      Carbonyl compounds           1             14       159           87
# ...                   ...         ...            ...       ...          ...
# 92911         Eicosanoids           1              7        78          137
# 92912         Eicosanoids           1              7        78          137
# 92913         Eicosanoids           1              7        78          137
# 92914         Eicosanoids           1              7        78          137
# 92915         Eicosanoids           1              7        78          137
#
#             HMDB
# 0      HMDB31492
# 1      HMDB31492
# 2      HMDB31492
# 3      HMDB31492
# 4      HMDB31492
# ...          ...
# 92911  HMDB12534
# 92912  HMDB12534
# 92913  HMDB12534
# 92914  HMDB12534
# 92915  HMDB12534
#
# [92916 rows x 18 columns]

# %%
filepath = base_path / ('%s_dis.csv' % dataset)
df1.drop(columns=['Unnamed: 0'], inplace=True)
df1.to_csv(filepath)
