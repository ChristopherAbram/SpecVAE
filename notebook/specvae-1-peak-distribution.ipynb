# %% [markdown]
# # Prepare MS/MS dataset
# Select n distinct compounds by unique InChIKey from specified dataset and export data to csv file.

# %%
import os
import numpy as np
import pandas as pd

from matchms.filtering import normalize_intensities, require_minimum_number_of_peaks, select_by_mz, select_by_relative_intensity
from matchms import calculate_scores, Spectrum

import specvae.utils as utils, specvae.dataset as dt
from specvae.dataset import Spectra

# %%
def spectrum_processing(s):
    s = normalize_intensities(s)
    s = select_by_mz(s, mz_from=0, mz_to=2500)
    s = require_minimum_number_of_peaks(s, n_required=1)
    # s = select_by_relative_intensity(s, intensity_from=0.001, intensity_to=1.0)
    return s

# %%
def parse_spectrum(row):
    string = row['spectrum']
    m = dt.SplitSpectrum()(string)
    mzs, ints = zip(*m)
    idx = np.argsort(np.array(mzs))
    s = Spectrum(mz=np.array(mzs)[idx], intensities=np.array(ints)[idx])
    s = spectrum_processing(s)
    return row if s else None

# %% [markdown]
# ## Load and preprocess dataset
# Apply preprocessing function on selected subset of molecules:
# - select spectra with peaks within m/z range \[0, 2500\],
# - discard spectra with less than 10 peaks,
# - discard spectra with intensities below 0.1

# %%
dataset = 'HMDB'
n_molecules = 10000

# %%
print("Load and preprocess %s validation data..." % dataset)
data_path = utils.get_project_path() / '.data' / dataset / ('%s_full.csv' % dataset)
df = Spectra.get_unique(n_molecules, csv_file=data_path)
X = df.apply(parse_spectrum, axis=1)
print("Preprocessing done!")
# Out:
# Load and preprocess HMDB validation data...
# Preprocessing done!

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'spectrum', 'collision_energy', 'HMDB_map', 'SMILES',
#        'split', 'id', 'ionization_mode', 'ionization_mode_id', 'kingdom',
#        'superclass', 'class', 'subclass', 'kingdom_id', 'superclass_id',
#        'class_id', 'subclass_id', 'HMDB'],
#       dtype='object')

# %% [markdown]
# ## Analyze dataset
# Compute maximum and average number of peaks across the entire dataset.

# %%
def to_num_peaks(row):
    string = row['spectrum']
    m = dt.SplitSpectrum()(string)
    mzs, ints = zip(*m)
    return len(mzs)

# %%
X = X.dropna(subset=['spectrum'])
X
# Out:
#        Unnamed: 0                                           spectrum  \
# 0               0  29.03912516:0.7243706179 57.03403978:4.5379311...
# 1               1  29.03912516:9.587454265 55.01838972:2.54439610...
# 2               2  27.0234751:6.640847978 29.03912516:6.54806256 ...
# 3               3  27.0234751:0.03173920628 29.00273965:0.0149975...
# 4               4  27.0234751:0.3171135208 29.00273965:0.47242358...
# ...           ...                                                ...
# 59995       59995  223.242576:2.727977493 233.2269259:2.281121111...
# 59996       59996  219.2112759:2.333845237 221.2269259:2.41941652...
# 59997       59997  233.2269259:0.5569748378 237.2582261:1.3758476...
# 59998       59998  59.01330434:0.9224031294 233.2269259:1.0072093...
# 59999       59999  41.00273965:3.367202251 43.01838972:2.03487395...
#
#        collision_energy          HMDB_map  \
# 0                    10  HMDB:HMDB0031492
# 1                    20  HMDB:HMDB0031492
# 2                    40  HMDB:HMDB0031492
# 3                    10  HMDB:HMDB0031492
# 4                    20  HMDB:HMDB0031492
# ...                 ...               ...
# 59995                20  HMDB:HMDB0050033
# 59996                40  HMDB:HMDB0050033
# 59997                10  HMDB:HMDB0050033
# 59998                20  HMDB:HMDB0050033
# 59999                40  HMDB:HMDB0050033
#
#                                                   SMILES  split         id  \
# 0                                         CCC(=O)C(=O)CC  train  HMDB31492
# 1                                         CCC(=O)C(=O)CC  train  HMDB31492
# 2                                         CCC(=O)C(=O)CC  train  HMDB31492
# 3                                         CCC(=O)C(=O)CC  train  HMDB31492
# 4                                         CCC(=O)C(=O)CC  train  HMDB31492
# ...                                                  ...    ...        ...
# 59995  [H][C@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COC(=O)CC...  train  HMDB50033
# 59996  [H][C@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COC(=O)CC...  train  HMDB50033
# 59997  [H][C@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COC(=O)CC...  train  HMDB50033
# 59998  [H][C@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COC(=O)CC...  train  HMDB50033
# 59999  [H][C@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COC(=O)CC...  train  HMDB50033
#
#        ionization_mode  ionization_mode_id            kingdom  \
# 0                    1                   1  Organic compounds
# 1                    1                   1  Organic compounds
# 2                    1                   1  Organic compounds
# 3                    0                   0  Organic compounds
# 4                    0                   0  Organic compounds
# ...                ...                 ...                ...
# 59995                1                   1  Organic compounds
# 59996                1                   1  Organic compounds
# 59997                0                   0  Organic compounds
# 59998                0                   0  Organic compounds
# 59999                0                   0  Organic compounds
#
#                             superclass                   class  \
# 0             Organic oxygen compounds  Organooxygen compounds
# 1             Organic oxygen compounds  Organooxygen compounds
# 2             Organic oxygen compounds  Organooxygen compounds
# 3             Organic oxygen compounds  Organooxygen compounds
# 4             Organic oxygen compounds  Organooxygen compounds
# ...                                ...                     ...
# 59995  Lipids and lipid-like molecules    Glycerophospholipids
# 59996  Lipids and lipid-like molecules    Glycerophospholipids
# 59997  Lipids and lipid-like molecules    Glycerophospholipids
# 59998  Lipids and lipid-like molecules    Glycerophospholipids
# 59999  Lipids and lipid-like molecules    Glycerophospholipids
#
#                                     subclass  kingdom_id  superclass_id  \
# 0                         Carbonyl compounds           1             14
# 1                         Carbonyl compounds           1             14
# 2                         Carbonyl compounds           1             14
# 3                         Carbonyl compounds           1             14
# 4                         Carbonyl compounds           1             14
# ...                                      ...         ...            ...
# 59995  Glycerophosphoglycerophosphoglycerols           1              7
# 59996  Glycerophosphoglycerophosphoglycerols           1              7
# 59997  Glycerophosphoglycerophosphoglycerols           1              7
# 59998  Glycerophosphoglycerophosphoglycerols           1              7
# 59999  Glycerophosphoglycerophosphoglycerols           1              7
#
#        class_id  subclass_id       HMDB
# 0           159           87  HMDB31492
# 1           159           87  HMDB31492
# 2           159           87  HMDB31492
# 3           159           87  HMDB31492
# 4           159           87  HMDB31492
# ...         ...          ...        ...
# 59995        88          167  HMDB50033
# 59996        88          167  HMDB50033
# 59997        88          167  HMDB50033
# 59998        88          167  HMDB50033
# 59999        88          167  HMDB50033
#
# [60000 rows x 18 columns]

# %%
Y = X.apply(to_num_peaks, axis=1)
Y
# Out:
# 0         6
# 1         6
# 2         6
# 3        23
# 4        23
#          ..
# 59995    31
# 59996    31
# 59997    31
# 59998    31
# 59999    31
# Length: 60000, dtype: int64

# %%
mm = Y.max()
Y.median(), Y.mean(), Y.max(), Y.min()
# Out:
# (31.0, 27.581766666666667, 31, 1)

# %%
Y.to_numpy()
# Out:
# array([ 6,  6,  6, ..., 31, 31, 31], dtype=int64)

# %%
from specvae.visualize import plot_distribution
import plotly.express as px
# plot_distribution(Y.to_numpy(), 'peaks numbers', 'sdc', 'sdc', bins=200)
px.histogram(Y, x=0)

# %% [markdown]
# ## Save csv file

# %%
# Save file in specified location
# filepath = utils.get_project_path() / '.data' / dataset / ('%s_score.csv' % dataset)
# X.to_csv(filepath)
